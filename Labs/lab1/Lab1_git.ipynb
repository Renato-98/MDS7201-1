# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Eduardo Moya
# - Ayudantes: Nicolás Ojeda, Melanie Peña, Valentina Rojas

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Valentina Abello
# - Nombre de alumno 2: Renato Pino

# %% [markdown]
# ### **Link de repositorio de GitHub:** [https://github.com/Renato-98/MDS7201-1](https://github.com/Renato-98/MDS7201-1)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Jueves a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. `Git` es un sistema de control de versiones distribuido (DVCS) que se utiliza para rastrear cambios en archivos y colaborar en proyectos de desarrollo de software, y se relaciona con el control de versiones puesto que permite llevar un registro de los cambios realizados en los archivos de un proyecto.
#
# 2. - Git es un sistema de control de versiones distribuido, mientras que Github es una plataforma web que utiliza Git como su sistema de control de versiones subyacente.
#    - Git almacena los repositorios de forma local, meintras que Github almacena los repositorios en servidores remotos en la nube.
#    - Git es una herramienta de linea de comando, mientras de Github entrega una interfaz gráfica.
#
# 3. Un hash es un identificador de cambio único que contiene 40 carácteres y que puede apuntar a un blob, un commit o un árbol, para el caso del commit este puede ser representado por los primeros 7 carácteres del hash, por ejemplo para el un hash cualquiera:
#
#    `a1b2C3d4e5F6g7H8i9J0k1L2m3N4o5P6Q7R8s9T1`
#
#    Para el caso de un commit bastaria con:
#
#    `a1b2C3d4`
#
# 4. Los elementos que componen la estructura de datos de git son:
#
# - Blob (Binary Large Object): Consiste en el contenido de un archivo en un determinado momento.
#
# - Tree: Consiste en el contenido de un directorio en un determinado momento.
#
# - Stage area: En esta area se ubican todos los archivos y modificaciones a estos, que pretenden incluirse en el proximo commit a realizar.
#
# - Commit: Un commit corresponde a un determinado instante de tiempo de un proyecto, en el cual se consideran tanto los archivos y modificaciones del proyecto en ese instante de tiempo.
#
# - Tag: Un Tag es una etiqueta que referencia un commit especifico.
#
# - Head: Es un puntero que referencia el último commit realizado y la rama actual.
#
# - Brach: Un Brach es una línea de desarrollo distinta a la línea principal del proyecto, la cual guarda una serie de commits. Estas ramas permiten trabajar en distintas partes de un proyecto de manera independiente sin que interfieran entre si.
#
# - Remote: Un Remote es una referencia a un repositorio remoto, como GitHub, en el cual se pueden respaldar todos los archivos locales.
#
# 5. Para crear un repositorio de manera local basta con utilizar el comando `git init`. Por otro lado, para realizar un seguimiento de los cambios realizado, en primer lugar, se deben usar los comandos `git add` y `git commit` para agregar los archivos al área Stage y guardar los cambios respectivamente. Finalmente, para ver el historial de cambios (historial de commits) de los archivos se debe ejecutar el comando `git log`.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. Falso, si se encuentran conflictos en las lineas de código modificadas Git no es capaza de solucionarlo automáticamente por lo que se tendria que hacer manualmente.
# 7. Falso, `git pull` extrae o actualiza el contenido de un repositorio repositorio remoto al repositorio local y se puede ejecutar varias veces, mientras que `git glone` crea una copia exacta del repositorio remoto al almacenamiento local y solo se ejecuta una vez.
# 8. Falso, `git status` muestra información sobre el estado actual de la rama respecto a su estado anterior, mientras que `git log` muestra información detallada sobre los commits realizados.
# 9. Verdadero, puedes volver a una revisión antigua usando `git checkout` y pasando el hash del commit (sin alterar la historia de los commits). También es posible descartar cambios  mediante `git reset` pasándole el hash del commit al que se quiere regresar o el numero de commits anteriores(si puede alterar la historia delos commits). Por ejemplo, para descartar los últimos 2 commits: `git reset --hard HEAD~2`
# 10. Falso, el comando `git commit` sirve para guardar cambios de manera local. Si se desea enviar cambios a un repositorio remoto, se debe utilizar el comando `git push`.

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# <code>Respuestas:</code>
#
# 11. El comando `git stash` sirve para guardar temporalmente los cambios realizados pero sin enviarlos al repositorio local, es decir, son cambios en los cuales todavia no se tiene la intención de realizar un `git commit`.Estos se guardan en un área llamada "stash" donde puedes almacenar temporalmente una captura de los cambios sin enviarlos al repositorio. Está separada del directorio de trabajo (working directory), del área de preparación (staging area), o del repositorio. Este comando es útil para no perder cambios de los cuales no se esta completamente seguro de oficializar en el repositorio o si has hecho cambios en una rama donde no estás listo para realizarle commit, pero necesitas cambiar a otra rama.
#
# 12. Como señalamos en la pregunta 9, el comando `git reset` se utiliza para volver al estado de un commit especifico, eliminando de esta forma todos los cambios efectuados desde el commit al cual se quiere regresar hasta el estado actual del código. Por otro lado, `git revert` tambien permite regresar a un commit especifico, pero sin eliminar los cambios efectuados entremedio a diferencia de `git reset`. El comando `git revert` solo elimina los cambios de un commit especifico creando un commit completamente nuevo, todo esto sin alterar el historial de commits.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> [https://github.com/Renato-98/Renato-98](https://github.com/Renato-98/Renato-98)
#
# <code>Link Presentacion 2:</code> [https://github.com/valentinaabello/valentinaabello](https://github.com/valentinaabello/valentinaabello)

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# `git clone https://github.com/MDS7202/lab1`

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>
#
# 1. Se crea el archivo <code>.gitignore</code> con:
# - videos/
# - *.txt
# - !texts/171.txt
# 2. Se realiza un <code>git add .gitignore</code>
# 3. Se realiza un <code>git commit -m 'se agrega .gitignore'</code>
# [Archivo .gitignore](.gitignore)

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 3. El objetivo del proyecto es emular los sonidos de animales ingresados por un usuario. La estructura del proyecto consiste en un archivo <code>README.md</code> con información breve del repositorio. Además contiene dos archivos <code>.py</code>, uno <code>animales.py</code> que define una función llamada 'animales' que recibe un 'input', la cual determina si este 'input' corresponde a un gato, perro o fox, entregando su sonido correspondiente ('miau', 'guau' o un video de youtube para el caso del zorro) y en caso de no ser uno de esos tres animales, entrega un error con el mensaje : "animal no reconocido :(". Por último, está el archivo <code>main.py</code> que en primera instancia importa la función 'animales' del archivo <code>animales.py</code> y solicita al usuario ingresar nombre de un animal para luego entregar el sonido mediante la función 'animales'.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 4. Se realiza con <code>git log --all --graph</code>. Obteniendo:
#
# ```
# * commit 9d02b8f8036ec5f33eeebc147a85dd4182c08252 (HEAD -> main)
# | Author: valentinaabello <valentina.abello@mail.udp.cl>
# | Date:   Tue Aug 20 22:47:27 2024 -0400
# |
# |     se agrega .gitignore
# |
# * commit 362fe21ee44f53ee944cee4ba484600308f83d78 (origin/new_features, origin/main, origin/HEAD)
# | Author: mezosky <ignacio.meza@ug.uchile.cl>
# | Date:   Thu Mar 23 21:47:34 2023 -0300
# |
# |     Se separa el proyecto en modulos
# |
# | * commit 25543a3baf77292baf849726784ca005473acab1 (origin/fix-ifs)
# |/  Author: Pablo Badilla <pbadilla.torrealba@gmail.com>
# |   Date:   Thu Mar 23 22:50:49 2023 -0300
# |
# |       fix ifs
# |
# * commit c8b1a62d7299552b0654f930d695b33109214111
# | Author: seba <stinoco@fen.uchile.cl>
# | Date:   Wed Mar 22 17:28:19 2023 -0300
# |
# |     se agrega funcion
# |
# * commit b262d86411a6b017e99bf0731e33a6787739247c
#   Author: seba <stinoco@fen.uchile.cl>
#   Date:   Wed Mar 22 17:25:30 2023 -0300
#
#       primer commit
# ```
# Considerando los últimos commits realizados, cada uno cuenta con un pequeño mensaje sobre qué se hizo pero de forma poco informativa, sin explicar las motivaciones de tales commits. En detalle:
#
# - "primer commit", no se especifica que es lo que se cambia o datos más especificos sobre el commit.
# - "se agrega funcion", no se especifica cual función se agregó ni su objetivo.
# - "se separa el proyecto en modulos", no se especifica los módulos ni para que son cada uno.
# - "fix ifs", no se especifica que fue lo que se arregló, muy conciso.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
#
# 5. Primero se revisa el archivo <code>main.py</code> mediante: <code>python main.py</code>, obteniendo lo siguiente:
#
# ```
# Ingrese el animalito para saber que dice:
# gato
# miau
# Traceback (most recent call last):
#   File "C:\Users\Valentina\lab1\main.py", line 6, in <module>
#     animales(animal)
#   File "C:\Users\Valentina\lab1\animales.py", line 14, in animales
#     raise ValueError('animal no reconocido :(')
# ValueError: animal no reconocido :(
# ```
# Donde el error se produce originalmente en la linea 14 del archivo <code>animales.py</code>, por lo que se realiza el siguiente comando <code>git blame animales.py</code> para conocer a la persona que lo realizó, obteniendo:
#
# ```
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 14)         raise ValueError('animal no reconocido :(')
# ```
#
# Por lo que el usuario fue **mezosky**.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# En primer lugar, el commit <code>c8b1a62</code> contiene solo un archivo, <code>main.py</code>, en el cual se encuentra la función animales y el if con él "__main__". Luego en el commit <code>362fe21</code> se separa la función animales y el if en dos archivos llamados <code>animales.py</code> y <code>main.py</code> respectivamente.
#
# Por último, en el commit <code>25543a</code> se vuelven a unir en un solo archivo <code>main.py</code> ambas funciones, con la diferencia de que en este caso en la función animales se ocupa el comando elif para los distintos valores que puede tomar el parametro input, a diferencia del primer commit (<code>c8b1a62</code>) en el cual se utiliza el comando if para todos los posibles valores que toma el parámetro en la función animales.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al realizar este `merge` ocurre un error que imposibilita la unión entre ramas. Lo anterior ocurre debido a la linea:
#
# - `from animales import animales`
#
# Dado que la rama `fix-ifs` no posee el archivo `animales.py`. Por ende al realizar un merge se esta importando un archivo que no existe.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Para solucionar el problema, se debe crear una nueva rama la cual contiene un archivo `main.py` y un archivo `animales.py` (como una rama que nace del commit `362fe21e` de **mezosky**). A continuación se presenta el código que deben presentar ambos archivos.

# %%
#archivo animales

def animales(input):
    
    '''
    Como hace el animalito?
    '''
    
    if input.lower() == 'gato':
        print('miau')
    elif input.lower() == 'perro':
        print('guau')
    elif input.lower() == 'fox':
        print('https://www.youtube.com/watch?v=jofNR_WkoCE')
    else:
        raise ValueError('animal no reconocido :('))

# %%
#archivo main. 
#Se eliminan lineas que definen la función animales. Esta función se define en un nuevo archivo llamado animales.

from animales import animales

if __name__ == '__main__':
    print("Ingrese el animalito para saber que dice:")
    animal = input()
    animales(animal)

# %% [markdown]
# Finalmente, esta rama si puede hacer un merge con el main sin lanzar un error y implementando la solución pensada en la rama fix ifs.

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
